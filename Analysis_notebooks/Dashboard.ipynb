# %% [markdown]
# # Student Performance & Mental Health Dashboard
#
# This notebook contains the interactive dashboard and analysis
# for the Students Performance and Mental Health project.
#
# **Author:** Birhanu Moges

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Dashboard notebook loaded successfully.")

# %%
# Example placeholder dataframe
data = {
    'Region': ['Addis Ababa', 'Oromia', 'Amhara'],
    'Average_Score': [78, 72, 69],
    'Stress_Level': [3.2, 3.8, 4.1]
}

df = pd.DataFrame(data)
df
